# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
import glob
import os
import numpy as np
from PIL import Image
import torchvision.models as models
import copy
from torchvision.utils import save_image
import PIL
import pandas as pd
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from lib import data_loader as dl
from lib import models as md
from lib import model_device_io as io
from torch.autograd import Variable

# %%
train_set = dl.OuluNpu('data/oulu_npu_cropped/train')
train_loader = DataLoader(train_set, batch_size=256, shuffle=True, num_workers=0)
test_set = dl.OuluNpu('data/oulu_npu_cropped/val')
test_loader = DataLoader(train_set, batch_size=512, shuffle=False, num_workers=0)

# %%
device = io.GetCudaDevice(cuda = 1, seed = 123, log=True)
model = md.ResNet().to(device)
optimizer = optim.Adam(model.parameters(), lr=0.0001, betas=(0.5, 0.999))
#io.loadModel('models/best.pth',model,optimizer)
# Out:
# Device used: cuda:1

# %%
def test():
    model.eval()
    loss, correct = 0, 0
    with torch.no_grad():
        for idx, datas in enumerate(test_loader):
            imgList, phone, session, human_id, access, _ = datas
            imgList = [img.to(device) for img in imgList]
            access = access.to(device)
            output = model(imgList)
            pred = output.max(1, keepdim=True)[1]
            correct += pred.eq(access.view_as(pred)).sum().item()
            loss += F.cross_entropy(output, access).item()*len(access)
                
    loss /= len(test_loader.dataset)
    percentage = 100.*correct/len(test_loader.dataset)
    print('***Validation Result:\tLoss: {:.4f}\tAccuraccy: {:.2f}% ({}/{})\n'.format(loss, percentage,
          correct, len(test_loader.dataset)))
    return percentage

def train(train_epoch = 100):
    best_acc = 0
    for epoch in range(train_epoch):
        model.train()
        for batch_idx, datas in enumerate(train_loader):
            optimizer.zero_grad()
            imgList, phone, session, human_id, access, _ = datas
            imgList = [img.to(device) for img in imgList]
            access = access.to(device)
                
            #train
            output = model(imgList)
            loss = F.cross_entropy(output, access)
            loss.backward()
            optimizer.step()
            
            #log    
            if (batch_idx+1) % max(1, int(len(train_loader)/5)) == 0:
                print('Training Epoch: {}/{}\tBatch: {}/{}\tLoss: {:.4f}'.format(epoch+1,
                       train_epoch, batch_idx+1, len(train_loader), loss.item()))
        acc = test()
        if acc > best_acc:
            best_acc = acc
            io.saveModel('models/best.pth', model, optimizer)

# %%
train()
# Out:
# Training Epoch: 1/100	Batch: 1/5	Loss: 1.6142
# Training Epoch: 1/100	Batch: 2/5	Loss: 1.7630
# Training Epoch: 1/100	Batch: 3/5	Loss: 1.5545
# Training Epoch: 1/100	Batch: 4/5	Loss: 1.4256
# Training Epoch: 1/100	Batch: 5/5	Loss: 1.3488
# ***Validation Result:	Loss: 1.2203	Accuraccy: 46.92% (563/1200)
#
# model saved to models/best.pth
# Training Epoch: 2/100	Batch: 1/5	Loss: 1.2379
# Training Epoch: 2/100	Batch: 2/5	Loss: 1.0392
# Training Epoch: 2/100	Batch: 3/5	Loss: 0.9899
# Training Epoch: 2/100	Batch: 4/5	Loss: 0.9508
# Training Epoch: 2/100	Batch: 5/5	Loss: 0.8748
# ***Validation Result:	Loss: 0.6537	Accuraccy: 69.08% (829/1200)
#
# model saved to models/best.pth
# Training Epoch: 3/100	Batch: 1/5	Loss: 0.7082
# Training Epoch: 3/100	Batch: 2/5	Loss: 0.7526
# Training Epoch: 3/100	Batch: 3/5	Loss: 0.7319
# Training Epoch: 3/100	Batch: 4/5	Loss: 0.5583
# Training Epoch: 3/100	Batch: 5/5	Loss: 0.5299
# ***Validation Result:	Loss: 0.4061	Accuraccy: 80.33% (964/1200)
#
# model saved to models/best.pth
# Training Epoch: 4/100	Batch: 1/5	Loss: 0.4191
# Training Epoch: 4/100	Batch: 2/5	Loss: 0.4250
# Training Epoch: 4/100	Batch: 3/5	Loss: 0.4572
# Training Epoch: 4/100	Batch: 4/5	Loss: 0.4003
# Training Epoch: 4/100	Batch: 5/5	Loss: 0.4257
# ***Validation Result:	Loss: 0.3296	Accuraccy: 81.08% (973/1200)
#
# model saved to models/best.pth
# Training Epoch: 5/100	Batch: 1/5	Loss: 0.3759
# Training Epoch: 5/100	Batch: 2/5	Loss: 0.2858
# Training Epoch: 5/100	Batch: 3/5	Loss: 0.3186
# Training Epoch: 5/100	Batch: 4/5	Loss: 0.2795
# Training Epoch: 5/100	Batch: 5/5	Loss: 0.3389
# ***Validation Result:	Loss: 0.2098	Accuraccy: 94.92% (1139/1200)
#
# model saved to models/best.pth
# Training Epoch: 6/100	Batch: 1/5	Loss: 0.2484
# Training Epoch: 6/100	Batch: 2/5	Loss: 0.2228
# Training Epoch: 6/100	Batch: 3/5	Loss: 0.2241
# Training Epoch: 6/100	Batch: 4/5	Loss: 0.1982
# Training Epoch: 6/100	Batch: 5/5	Loss: 0.2445
# ***Validation Result:	Loss: 0.0856	Accuraccy: 98.33% (1180/1200)
#
# model saved to models/best.pth
# Training Epoch: 7/100	Batch: 1/5	Loss: 0.1147
# Training Epoch: 7/100	Batch: 2/5	Loss: 0.1178
# Training Epoch: 7/100	Batch: 3/5	Loss: 0.1542
# Training Epoch: 7/100	Batch: 4/5	Loss: 0.1107
# Training Epoch: 7/100	Batch: 5/5	Loss: 0.1713
# ***Validation Result:	Loss: 0.0853	Accuraccy: 97.50% (1170/1200)
#
# Training Epoch: 8/100	Batch: 1/5	Loss: 0.1902
# Training Epoch: 8/100	Batch: 2/5	Loss: 0.1226
# Training Epoch: 8/100	Batch: 3/5	Loss: 0.0628
# Training Epoch: 8/100	Batch: 4/5	Loss: 0.0954
# Training Epoch: 8/100	Batch: 5/5	Loss: 0.0753
# ***Validation Result:	Loss: 0.0300	Accuraccy: 99.00% (1188/1200)
#
# model saved to models/best.pth
# Training Epoch: 9/100	Batch: 1/5	Loss: 0.0667
# Training Epoch: 9/100	Batch: 2/5	Loss: 0.0281
# Training Epoch: 9/100	Batch: 3/5	Loss: 0.0307
# Training Epoch: 9/100	Batch: 4/5	Loss: 0.0470
# Training Epoch: 9/100	Batch: 5/5	Loss: 0.0395
# ***Validation Result:	Loss: 0.0489	Accuraccy: 98.50% (1182/1200)
#
# Training Epoch: 10/100	Batch: 1/5	Loss: 0.0533
# Training Epoch: 10/100	Batch: 2/5	Loss: 0.0073
# Training Epoch: 10/100	Batch: 3/5	Loss: 0.0061
# Training Epoch: 10/100	Batch: 4/5	Loss: 0.0107
# Training Epoch: 10/100	Batch: 5/5	Loss: 0.1370
# ***Validation Result:	Loss: 0.0107	Accuraccy: 99.67% (1196/1200)
#
# model saved to models/best.pth
# Training Epoch: 11/100	Batch: 1/5	Loss: 0.0089
# Training Epoch: 11/100	Batch: 2/5	Loss: 0.0091
# Training Epoch: 11/100	Batch: 3/5	Loss: 0.0090
# Training Epoch: 11/100	Batch: 4/5	Loss: 0.0459
# Training Epoch: 11/100	Batch: 5/5	Loss: 0.0483
# ***Validation Result:	Loss: 0.0122	Accuraccy: 99.67% (1196/1200)
#
# Training Epoch: 12/100	Batch: 1/5	Loss: 0.0276
# Training Epoch: 12/100	Batch: 2/5	Loss: 0.0118
# Training Epoch: 12/100	Batch: 3/5	Loss: 0.0037
# Training Epoch: 12/100	Batch: 4/5	Loss: 0.0037
# Training Epoch: 12/100	Batch: 5/5	Loss: 0.0493
# ***Validation Result:	Loss: 0.0101	Accuraccy: 99.75% (1197/1200)
#
# model saved to models/best.pth
# Training Epoch: 13/100	Batch: 1/5	Loss: 0.0274
# Training Epoch: 13/100	Batch: 2/5	Loss: 0.0113
# Training Epoch: 13/100	Batch: 3/5	Loss: 0.0078
# Training Epoch: 13/100	Batch: 4/5	Loss: 0.0189
# Training Epoch: 13/100	Batch: 5/5	Loss: 0.0084
# ***Validation Result:	Loss: 0.0049	Accuraccy: 99.92% (1199/1200)
#
# model saved to models/best.pth
# Training Epoch: 14/100	Batch: 1/5	Loss: 0.0046
# Training Epoch: 14/100	Batch: 2/5	Loss: 0.0026
# Training Epoch: 14/100	Batch: 3/5	Loss: 0.0092
# Training Epoch: 14/100	Batch: 4/5	Loss: 0.0055
# Training Epoch: 14/100	Batch: 5/5	Loss: 0.0036
# ***Validation Result:	Loss: 0.0072	Accuraccy: 99.75% (1197/1200)
#
# Training Epoch: 15/100	Batch: 1/5	Loss: 0.0011
# Training Epoch: 15/100	Batch: 2/5	Loss: 0.0068
# Training Epoch: 15/100	Batch: 3/5	Loss: 0.0224
# Training Epoch: 15/100	Batch: 4/5	Loss: 0.0036
# Training Epoch: 15/100	Batch: 5/5	Loss: 0.0065
# ***Validation Result:	Loss: 0.0049	Accuraccy: 99.83% (1198/1200)
#
# Training Epoch: 16/100	Batch: 1/5	Loss: 0.0049
# Training Epoch: 16/100	Batch: 2/5	Loss: 0.0053
# Training Epoch: 16/100	Batch: 3/5	Loss: 0.0134
# Training Epoch: 16/100	Batch: 4/5	Loss: 0.0016
# Training Epoch: 16/100	Batch: 5/5	Loss: 0.0096
# ***Validation Result:	Loss: 0.0124	Accuraccy: 99.58% (1195/1200)
#
# Training Epoch: 17/100	Batch: 1/5	Loss: 0.0217
# Training Epoch: 17/100	Batch: 2/5	Loss: 0.0052
# Training Epoch: 17/100	Batch: 3/5	Loss: 0.0184
# Training Epoch: 17/100	Batch: 4/5	Loss: 0.0358
# Training Epoch: 17/100	Batch: 5/5	Loss: 0.0012
# ***Validation Result:	Loss: 0.0040	Accuraccy: 99.83% (1198/1200)
#
# Training Epoch: 18/100	Batch: 1/5	Loss: 0.0066
# Training Epoch: 18/100	Batch: 2/5	Loss: 0.0036
# Training Epoch: 18/100	Batch: 3/5	Loss: 0.0104
# Training Epoch: 18/100	Batch: 4/5	Loss: 0.0110
# Training Epoch: 18/100	Batch: 5/5	Loss: 0.0121
# ***Validation Result:	Loss: 0.0026	Accuraccy: 100.00% (1200/1200)
#
# model saved to models/best.pth
# Training Epoch: 19/100	Batch: 1/5	Loss: 0.0039
# Training Epoch: 19/100	Batch: 2/5	Loss: 0.0162
# Training Epoch: 19/100	Batch: 3/5	Loss: 0.0008
# Training Epoch: 19/100	Batch: 4/5	Loss: 0.0017
# Training Epoch: 19/100	Batch: 5/5	Loss: 0.0132
# ***Validation Result:	Loss: 0.0024	Accuraccy: 100.00% (1200/1200)
#
# Training Epoch: 20/100	Batch: 1/5	Loss: 0.0022
# Training Epoch: 20/100	Batch: 2/5	Loss: 0.0055
# Training Epoch: 20/100	Batch: 3/5	Loss: 0.0038
# Training Epoch: 20/100	Batch: 4/5	Loss: 0.0045
# Training Epoch: 20/100	Batch: 5/5	Loss: 0.0007
# ***Validation Result:	Loss: 0.0026	Accuraccy: 99.83% (1198/1200)
#
# Training Epoch: 21/100	Batch: 1/5	Loss: 0.0014
# Training Epoch: 21/100	Batch: 2/5	Loss: 0.0005
# Training Epoch: 21/100	Batch: 3/5	Loss: 0.0035
# Training Epoch: 21/100	Batch: 4/5	Loss: 0.0063
# Training Epoch: 21/100	Batch: 5/5	Loss: 0.0022
# ***Validation Result:	Loss: 0.0018	Accuraccy: 99.92% (1199/1200)
#
# Training Epoch: 22/100	Batch: 1/5	Loss: 0.0009
